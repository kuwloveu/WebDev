# %%
a = int(input())
b = int(input())

for i in range(a, b + 1):
    if i % 2 == 0:
        print(i, end=" ")

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())

for i in range(a, b + 1):
    if i % d == c:
        print(i, end=" ")

# %%
a = int(input())
b = int(input())

i = 1
while i * i <= b:
    if i * i >= a:
        print(i * i, end=" ")
    i += 1

# %%
x = int(input())

for i in range(2, x + 1):
    if x % i == 0:
        print(i)
        break

# %%
x = int(input())

for i in range(1, x + 1):
    if x % i == 0:
        print(i, end=" ")

# %%
x = int(input())
count = 0
i = 1

while i * i <= x:
    if x % i == 0:
        count += 2 if i * i != x else 1
    i += 1

print(count)
# Out:
# 6

# %%
total = 0
for _ in range(100):
    total += int(input())
print(total)

# %%
N = int(input())
total = 0

for _ in range(N):
    total += int(input())

print(total)

# %%
N = int(input())
count = 0

for _ in range(N):
    if int(input()) == 0:
        count += 1

print(count)

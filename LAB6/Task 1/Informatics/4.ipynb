# %%
N = int(input())
i = 1

while i * i <= N:
    print(i * i)
    i += 1

# %%
N = int(input())

for i in range(2, N + 1):
    if N % i == 0:
        print(i)
        break
# Out:
# 2

# %%
N = int(input())
x = 1

while x <= N:
    print(x, end=" ")
    x *= 2

# %%
N = int(input())
x = 1

while x < N:
    x *= 2

print("YES" if x == N else "NO")
# Out:
# NO

# %%
N = int(input())
k = 0
x = 1

while x < N:
    x *= 2
    k += 1

print(k)

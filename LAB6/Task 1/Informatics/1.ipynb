# %%
a = int(input())

b = int(input())

print( (a**2 + b**2)**(1/2) )
# Out:
# 5.0

# %%
# The next number for the number 179 is 180.
# The previous number for the number 179 is 178.

a = int(input())

print(f"The next number for the number {a} is {a + 1}.")
print(f"The previous number for the number {a} is {a-1}.")
# Out:
# The next number for the number 190 is 191.
# The previous number for the number 190 is 189.

# %%
n = int(input())
k = int(input())

print(k // n)
# Out:
# 4

# %%
n = int(input())
k = int(input())

print(k % n)
# Out:
# 2

# %%
v = int(input())
t = int(input())

s = v * t

if(v > 0):
    print(s - 109)

else:
    print(s + 109)
# Out:
# 108
